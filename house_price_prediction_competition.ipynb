# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
# %matplotlib inline
df=pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ### Dropping the records with a missing target variable.

# %%
df.dropna(axis=0,subset=['SalePrice'],inplace=True)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.drop('Id', axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df['MSSubClass']
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %% [markdown]
# ### It seems to be of type integer, but upon reading the data desciption, we can infer that it's a categorical feature. Let's check the unique values in this feature.

# %%
df['MSSubClass'].unique()
# Out:
# array([ 60,  20,  70,  50, 190,  45,  90, 120,  30,  85,  80, 160,  75,
#        180,  40], dtype=int64)

# %% [markdown]
# ### As expected, it is a categorical feature, hence it is better to convert it into one.

# %%
df['MSSubClass'] = df['MSSubClass'].astype('O')

# %%
df['MSSubClass']
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: object

# %% [markdown]
# ## Month in which house was sold

# %%
df['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %% [markdown]
# ### Hence we need to convert it to categorical dtype.

# %%
df['MoSold'] = df['MoSold'].astype('O')

# %%
df['MoSold'].unique()
# Out:
# array([2, 5, 9, 12, 10, 8, 11, 4, 1, 7, 3, 6], dtype=object)

# %% [markdown]
# ## Year that garage was built

# %%
df['GarageYrBlt'].unique()
# Out:
# array([2003., 1976., 2001., 1998., 2000., 1993., 2004., 1973., 1931.,
#        1939., 1965., 2005., 1962., 2006., 1960., 1991., 1970., 1967.,
#        1958., 1930., 2002., 1968., 2007., 2008., 1957., 1920., 1966.,
#        1959., 1995., 1954., 1953.,   nan, 1983., 1977., 1997., 1985.,
#        1963., 1981., 1964., 1999., 1935., 1990., 1945., 1987., 1989.,
#        1915., 1956., 1948., 1974., 2009., 1950., 1961., 1921., 1900.,
#        1979., 1951., 1969., 1936., 1975., 1971., 1923., 1984., 1926.,
#        1955., 1986., 1988., 1916., 1932., 1972., 1918., 1980., 1924.,
#        1996., 1940., 1949., 1994., 1910., 1978., 1982., 1992., 1925.,
#        1941., 2010., 1927., 1947., 1937., 1942., 1938., 1952., 1928.,
#        1922., 1934., 1906., 1914., 1946., 1908., 1929., 1933.])

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 81

# %% [markdown]
# ### Since we are getting some NaN values for the year when garage was built, we are going to fill  with it 0 and create a new feature which captures where the garage year was not available.

# %%
df['HasGarage'] = df['GarageYrBlt'].apply(lambda x:1 if pd.isnull(x) else 0)

# %%
df['GarageYrBlt'].fillna(0, inplace = True)

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 0

# %%
df[df['HasGarage']==1][['HasGarage','GarageYrBlt']]
# Out:
#       HasGarage  GarageYrBlt
# 39            1          0.0
# 48            1          0.0
# 78            1          0.0
# 88            1          0.0
# 89            1          0.0
# ...         ...          ...
# 1349          1          0.0
# 1407          1          0.0
# 1449          1          0.0
# 1450          1          0.0
# 1453          1          0.0
#
# [81 rows x 2 columns]

# %%
df[df['HasGarage']==0][['HasGarage','GarageYrBlt']]
# Out:
#       HasGarage  GarageYrBlt
# 0             0       2003.0
# 1             0       1976.0
# 2             0       2001.0
# 3             0       1998.0
# 4             0       2000.0
# ...         ...          ...
# 1455          0       1999.0
# 1456          0       1978.0
# 1457          0       1941.0
# 1458          0       1950.0
# 1459          0       1965.0
#
# [1379 rows x 2 columns]

# %% [markdown]
# ## Masonry Veneer Area

# %%
df['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 8

# %% [markdown]
# ### Hence we can create a new feature which indicates the missingness of this feature.

# %%
df['NoMasVnrArea'] = df['MasVnrArea'].apply(lambda x : 1 if pd.isnull(x) else 0)

# %%
df['MasVnrArea'].fillna(0, inplace = True)

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
df[df['NoMasVnrArea']==1][['NoMasVnrArea','MasVnrArea']]
# Out:
#       NoMasVnrArea  MasVnrArea
# 234              1         0.0
# 529              1         0.0
# 650              1         0.0
# 936              1         0.0
# 973              1         0.0
# 977              1         0.0
# 1243             1         0.0
# 1278             1         0.0

# %%
df[df['NoMasVnrArea']==0][['NoMasVnrArea','MasVnrArea']]
# Out:
#       NoMasVnrArea  MasVnrArea
# 0                0       196.0
# 1                0         0.0
# 2                0       162.0
# 3                0         0.0
# 4                0       350.0
# ...            ...         ...
# 1455             0         0.0
# 1456             0       119.0
# 1457             0         0.0
# 1458             0         0.0
# 1459             0         0.0
#
# [1452 rows x 2 columns]

# %% [markdown]
# ## Lets have a quick visual on the heatmap for numerical variables, to get an idea on multicollinearity

# %%
fig = plt.figure(figsize=(15,7))
corrmat = df.corr(numeric_only=True)
sbn.heatmap(corrmat, vmin = -0.8, vmax = 0.8, cmap = 'tab20')
# Out:
# <Axes: >

# %% [markdown]
# ### 1.BsmtFullBath and BsmtFinSF1 are having fair positive correlation, which is obvious, as more bathroom result in more basement area.
# ### 2.1stFlrSF anf TotalBsmtSF are having similar correlation, which is reasonable, as basements are generally as large as the first floors.
# ### 3.GrLivArea and SalePrice are having posiitve correlation, meaning more total area above ground leads to more price.
# ### 4.GarageCars and SalePrice are positvely correlated, obviously, as more the cars a garage can hold, more the facilities and area.

# %% [markdown]
# ## Now lets analyze the main feature, our target feature: Sale Price.

# %%
sbn.histplot(df['SalePrice'], kde = True)
# Out:
# C:\Users\rushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
df['SalePrice'].kurtosis()
# Out:
# 6.536281860064529

# %%
df['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %% [markdown]
# ### So it has considerable positive skewness and a leptokurtic shape, and we need to handle it by applying log transform later.

# %%
fig  = plt.figure(figsize=(15,7))
sales_cols = list(corrmat['SalePrice'].sort_values(ascending=False)[1:11].index)
sales_cols.append('SalePrice')
sales_corr = df[sales_cols].corr()
sbn.heatmap(sales_corr, cmap = 'tab20')
# Out:
# <Axes: >

# %% [markdown]
# ### Total Rooms Above Ground and Year Built are strongly negatively correlated, which means that the older the house, more the number of finished rooms above ground.This could be true because of more construction space available in older days.
# ### OverallQual and GrLivarea are highly correlated to Sale price, which is obvious.

# %%
fig  = plt.figure(figsize=(15,7))
sbn.scatterplot(x='YearBuilt', y='TotRmsAbvGrd', data=df)
# Out:
# <Axes: xlabel='YearBuilt', ylabel='TotRmsAbvGrd'>

# %%
df.groupby(pd.cut(df['YearBuilt'], bins=[1870,1900,1950,2000,2020]))['TotRmsAbvGrd'].mean()
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_11740\2825443043.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df['YearBuilt'], bins=[1870,1900,1950,2000,2020]))['TotRmsAbvGrd'].mean()
# YearBuilt
# (1870, 1900]    8.400000
# (1900, 1950]    6.274760
# (1950, 2000]    6.340369
# (2000, 2020]    6.967033
# Name: TotRmsAbvGrd, dtype: float64

# %% [markdown]
# ### But from the scatterplot, it is evident that there is no clear trend among the variables, so OverallQual and GrLivarea are not strongly related.

# %%
fig  = plt.figure(figsize=(15,7))
sbn.lineplot(y='SalePrice', x='OverallQual', data=df)
# Out:
# C:\Users\rushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %%
fig  = plt.figure(figsize=(15,7))
sbn.lineplot(x='SalePrice', y='GrLivArea', data=df)
# Out:
# C:\Users\rushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SalePrice', ylabel='GrLivArea'>

# %%
fig  = plt.figure(figsize=(15,7))
sales_cols = list(corrmat['SalePrice'].sort_values(ascending=True)[1:11].index)
sales_cols.append('SalePrice')
sales_corr = df[sales_cols].corr()
sbn.heatmap(sales_corr, cmap = 'tab20')
# Out:
# <Axes: >

# %%
corrmat['SalePrice'][['GarageArea','GarageCars']]
# Out:
# GarageArea    0.623431
# GarageCars    0.640409
# Name: SalePrice, dtype: float64

# %%
features_with_na=[feature for feature in df.columns if df[feature].isnull().sum()]
features_with_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for i in features_with_na:
    print(i,'has',df[i].isnull().sum()/len(df)*100,'% missing values')
# Out:
# LotFrontage has 17.73972602739726 % missing values
# Alley has 93.76712328767123 % missing values
# MasVnrType has 59.726027397260275 % missing values
# BsmtQual has 2.5342465753424657 % missing values
# BsmtCond has 2.5342465753424657 % missing values
# BsmtExposure has 2.6027397260273974 % missing values
# BsmtFinType1 has 2.5342465753424657 % missing values
# BsmtFinType2 has 2.6027397260273974 % missing values
# Electrical has 0.0684931506849315 % missing values
# FireplaceQu has 47.26027397260274 % missing values
# GarageType has 5.5479452054794525 % missing values
# GarageFinish has 5.5479452054794525 % missing values
# GarageQual has 5.5479452054794525 % missing values
# GarageCond has 5.5479452054794525 % missing values
# PoolQC has 99.52054794520548 % missing values
# Fence has 80.75342465753424 % missing values
# MiscFeature has 96.30136986301369 % missing values

# %%
for feature in features_with_na:
    data = df.copy()
    
    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    # let's calculate the mean SalePrice where the information is missing or present
    data.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.title(feature)
    plt.show()

# %%
numerical_features=[i for i in df.columns if df[i].dtype!='O']

len(numerical_features)
# Out:
# 38

# %%
year_feature=[feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for i in year_feature:
    print(i,df[i].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
for feature in year_feature:
    if feature!='YrSold':
        data=df.copy()
        ## We will capture the difference between year variable and year the house was sold for
        data[feature]=data['YrSold']-data[feature]

        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
discrete_features=[feature for feature in numerical_features if df[feature].nunique()<25 and feature not in year_feature+['SalePrice']]
discrete_features
# Out:
# ['OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'HasGarage',
#  'NoMasVnrArea']

# %%
for feature in discrete_features:
    data=df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %%
continuous_features=[feature for feature in numerical_features if feature not in discrete_features+year_feature+['Id']]
continuous_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for i in continuous_features:
    data=df.copy()
    data[i].hist(bins=25)
    plt.xlabel(i)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ### As we can see,the variables are somewhat normally distributed,hence we will apply log transformation later on,so that the algorithm can work on the data in a better manner.

# %%
for feature in continuous_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
for feature in numerical_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
#log of 0 is not defined
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.show()

# %%
categorical_features=[feature for feature in df.columns if feature not in numerical_features]
categorical_features
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MoSold',
#  'SaleType',
#  'SaleCondition']

# %%
for i in categorical_features:
    print("The feature {} has {} unique values".format(i,df[i].nunique()))
# Out:
# The feature MSSubClass has 15 unique values
# The feature MSZoning has 5 unique values
# The feature Street has 2 unique values
# The feature Alley has 2 unique values
# The feature LotShape has 4 unique values
# The feature LandContour has 4 unique values
# The feature Utilities has 2 unique values
# The feature LotConfig has 5 unique values
# The feature LandSlope has 3 unique values
# The feature Neighborhood has 25 unique values
# The feature Condition1 has 9 unique values
# The feature Condition2 has 8 unique values
# The feature BldgType has 5 unique values
# The feature HouseStyle has 8 unique values
# The feature RoofStyle has 6 unique values
# The feature RoofMatl has 8 unique values
# The feature Exterior1st has 15 unique values
# The feature Exterior2nd has 16 unique values
# The feature MasVnrType has 3 unique values
# The feature ExterQual has 4 unique values
# The feature ExterCond has 5 unique values
# The feature Foundation has 6 unique values
# ...

# %%
for i in categorical_features:
    data=df.copy()
    data.groupby(i)['SalePrice'].median().plot.bar()
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df,df['SalePrice'],test_size=0.1,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((1314, 83), (146, 83))

# %%
features_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes=='O']

for feature in features_nan:
    print("{}: {}% missing values".format(feature,df[feature].isnull().sum()*100/len(df[feature])))
# Out:
# Alley: 93.76712328767124% missing values
# MasVnrType: 59.726027397260275% missing values
# BsmtQual: 2.5342465753424657% missing values
# BsmtCond: 2.5342465753424657% missing values
# BsmtExposure: 2.6027397260273974% missing values
# BsmtFinType1: 2.5342465753424657% missing values
# BsmtFinType2: 2.6027397260273974% missing values
# FireplaceQu: 47.26027397260274% missing values
# GarageType: 5.5479452054794525% missing values
# GarageFinish: 5.5479452054794525% missing values
# GarageQual: 5.5479452054794525% missing values
# GarageCond: 5.5479452054794525% missing values
# PoolQC: 99.52054794520548% missing values
# Fence: 80.75342465753425% missing values
# MiscFeature: 96.3013698630137% missing values

# %%
## Replace missing value with a new value
def replace_cat_feature(df,features_nan):
    data=df.copy()
    data[features_nan]=data[features_nan].fillna('Missing')
    return data

df=replace_cat_feature(df,features_nan)

# %%
df[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
df.head()
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1         60       RL         65.0     8450   Pave  Missing      Reg
# 1   2         20       RL         80.0     9600   Pave  Missing      Reg
# 2   3         60       RL         68.0    11250   Pave  Missing      IR1
# 3   4         70       RL         60.0     9550   Pave  Missing      IR1
# 4   5         60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ...    Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...  Missing     Missing       0      2   2008
# 1         Lvl    AllPub  ...  Missing     Missing       0      5   2007
# 2         Lvl    AllPub  ...  Missing     Missing       0      9   2008
# 3         Lvl    AllPub  ...  Missing     Missing       0      2   2006
# 4         Lvl    AllPub  ...  Missing     Missing       0     12   2008
#
#   SaleType SaleCondition  SalePrice  HasGarage  NoMasVnrArea
# ...

# %%
numerical_with_nan=[feature for feature in df.columns if df[feature].isnull().sum()>0 and df[feature].dtypes!='O']

## We will print the numerical nan variables and percentage of missing values

for feature in numerical_with_nan:
    print("{}: {}% missing value".format(feature,df[feature].isnull().sum()*100/len(df[feature])))
# Out:
# LotFrontage: 17.73972602739726% missing value

# %%
## Replacing the numerical Missing Values

for feature in numerical_with_nan:
    ## We will replace by using median since there are outliers
    median_value=df[feature].median()
    
    ## create a new feature to capture nan values
    df[feature+'nan']=np.where(df[feature].isnull(),1,0)
    df[feature].fillna(median_value,inplace=True)
    
df[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# dtype: int64

# %%
df.head(50)
# Out:
#     Id MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0    1         60       RL         65.0     8450   Pave  Missing      Reg
# 1    2         20       RL         80.0     9600   Pave  Missing      Reg
# 2    3         60       RL         68.0    11250   Pave  Missing      IR1
# 3    4         70       RL         60.0     9550   Pave  Missing      IR1
# 4    5         60       RL         84.0    14260   Pave  Missing      IR1
# 5    6         50       RL         85.0    14115   Pave  Missing      IR1
# 6    7         20       RL         75.0    10084   Pave  Missing      Reg
# 7    8         60       RL         69.0    10382   Pave  Missing      IR1
# 8    9         50       RM         51.0     6120   Pave  Missing      Reg
# 9   10        190       RL         50.0     7420   Pave  Missing      Reg
# 10  11         20       RL         70.0    11200   Pave  Missing      Reg
# 11  12         60       RL         85.0    11924   Pave  Missing      IR1
# ...

# %%
## Temporal Variables (Date Time Variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    df[feature]=df['YrSold']-df[feature]

df.head()
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1         60       RL         65.0     8450   Pave  Missing      Reg
# 1   2         20       RL         80.0     9600   Pave  Missing      Reg
# 2   3         60       RL         68.0    11250   Pave  Missing      IR1
# 3   4         70       RL         60.0     9550   Pave  Missing      IR1
# 4   5         60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  HasGarage  NoMasVnrArea  LotFrontagenan
# ...

# %%
df[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']

for feature in num_features:
    df[feature]=np.log(df[feature])

# %%
df[num_features]
# Out:
#       LotFrontage   LotArea  1stFlrSF  GrLivArea
# 0        4.174387  9.041922  6.752270   7.444249
# 1        4.382027  9.169518  7.140453   7.140453
# 2        4.219508  9.328123  6.824374   7.487734
# 3        4.094345  9.164296  6.867974   7.448334
# 4        4.430817  9.565214  7.043160   7.695303
# ...           ...       ...       ...        ...
# 1455     4.127134  8.976768  6.859615   7.406711
# 1456     4.442651  9.486076  7.636752   7.636752
# 1457     4.189655  9.109636  7.080026   7.757906
# 1458     4.219508  9.181632  6.982863   6.982863
# 1459     4.317488  9.204020  7.135687   7.135687
#
# [1460 rows x 4 columns]

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MoSold',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_features:
    temp=df.groupby(feature).count()/len(df[feature])
    temp_df=temp[temp>0.01].index
    df[feature]=np.where(df[feature].isin(temp_df),df[feature],'Rare_var')

# %%
df.head(100)
# Out:
#      Id MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0     1         60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1     2         20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2     3         60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3     4         70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4     5         60       RL     4.430817  9.565214   Pave  Missing      IR1
# ..  ...        ...      ...          ...       ...    ...      ...      ...
# 95   96         60       RL     4.234107  9.186560   Pave  Missing      IR2
# 96   97         20       RL     4.356709  9.236398   Pave  Missing      IR1
# 97   98         20       RL     4.290459  9.298443   Pave  Missing      Reg
# 98   99         30       RL     4.442651  9.270965   Pave  Missing      Reg
# 99  100         20       RL     4.343805  9.139918   Pave  Missing      IR1
#
# ...

# %%
data=pd.get_dummies(df)
data
# Out:
#         Id  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1     4.174387  9.041922            7            5          5
# 1        2     4.382027  9.169518            6            8         31
# 2        3     4.219508  9.328123            7            5          7
# 3        4     4.094345  9.164296            7            5         91
# 4        5     4.430817  9.565214            8            5          8
# ...    ...          ...       ...          ...          ...        ...
# 1455  1456     4.127134  8.976768            6            5          8
# 1456  1457     4.442651  9.486076            6            6         32
# 1457  1458     4.189655  9.109636            7            9         69
# 1458  1459     4.219508  9.181632            5            6         60
# 1459  1460     4.317488  9.204020            5            6         43
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# ...

# %%
X=data.drop(['Id','SalePrice'],axis=1)
y=data['SalePrice']

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
lasso_model=SelectFromModel(Lasso(alpha=0.005,random_state=0))
lasso_model.fit(X,y)
# Out:
# C:\Users\rushi\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.097e+11, tolerance: 9.208e+08
#   model = cd_fast.enet_coordinate_descent(
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
lasso_model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
important_features = X.columns[(lasso_model.get_support())]
print('total features: {}'.format((X.shape[1])))
print('selected features: {}'.format(len(important_features)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(lasso_model.estimator_.coef_ == 0)))
# Out:
# total features: 331
# selected features: 326
# features with coefficients shrank to zero: 3

# %%
X=X[important_features]

# %%
X
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        4.174387  9.041922            7            5          5
# 1        4.382027  9.169518            6            8         31
# 2        4.219508  9.328123            7            5          7
# 3        4.094345  9.164296            7            5         91
# 4        4.430817  9.565214            8            5          8
# ...           ...       ...          ...          ...        ...
# 1455     4.127134  8.976768            6            5          8
# 1456     4.442651  9.486076            6            6         32
# 1457     4.189655  9.109636            7            9         69
# 1458     4.219508  9.181632            5            6         60
# 1459     4.317488  9.204020            5            6         43
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# 0                5       196.0         706           0        150  ...
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
yhat=linear.predict(X_test)
print("The accuracy is:",mean_absolute_error(y_test,yhat))
# Out:
# The accuracy is: 23746.17608367829

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest=RandomForestRegressor()
random_forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_yhat=random_forest.predict(X_test)
print("THe accuracy is:",mean_absolute_error(y_test,rf_yhat))
# Out:
# THe accuracy is: 17579.754520547947

# %% [markdown]
# ## References :
# ## 1.https://www.kaggle.com/code/pmarcelino/comprehensive-data-exploration-with-python
